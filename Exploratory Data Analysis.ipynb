# %% [markdown]
# # Exploratory Data Analysis

# %%
#Importing Necessary Packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Importing Data
data=pd.read_excel('INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls')
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %%
plt.figure(figsize=(10,5))
sns.barplot(data['EmpDepartment'],data['PerformanceRating'])
plt.title("Department wise Performance")
plt.show()
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# High Performance can be seen in Development Department and second highest is Data Science Department.

# %%
#Plotting all the Departments in one graph by using CrossTab
plt.figure(figsize=(20,10))
pd.crosstab(data.EmpDepartment,data.PerformanceRating).plot(kind='bar')
plt.xlabel('EmpDepartment')
plt.title("Performance Rating for each Department")
plt.show()

# %%
plt.figure(figsize=(15,10))
a=sns.countplot(x='EmpDepartment',hue='Gender',data=data)
plt.title('Number of Males and Females in each Department')
plt.show()

# %% [markdown]
# Male Employees are higher than Female Employees in Every Department.

# %%
plt.figure(figsize=(30,20))
sns.countplot(data.EmpJobRole,hue=data.PerformanceRating)
plt.title("Performance Rating based on Job Role")
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Performance Rating based on Job Role')

# %% [markdown]
# When compared to other job Roles Developer role Employees are trying hard.

# %%
plt.figure(figsize=(20,5))
a=sns.countplot(data.EmpDepartment,hue=data.Attrition)
plt.title('Attrition for each Department')
plt.show()
# Out:
# C:\Users\Bhaskar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
